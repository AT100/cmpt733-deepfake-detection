# %% [markdown]
# <a href="https://colab.research.google.com/github/AT100/cmpt733-deepfake-detection/blob/main/Kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Configuration environment
import os

os.environ['KAGGLE_USERNAME'] = "" # username from the json file
os.environ['KAGGLE_KEY'] = "" # key from the json file

# %%
# !kaggle datasets list -s deepfake
# Out:
# ...
# ref                                               title                                      size  lastUpdated          downloadCount
# ------------------------------------------------  ----------------------------------------  -----  -------------------  -------------
# khoongweihao/deepfake-xception-trained-model      Deepfake Xception Trained Model           467MB  2020-02-25 01:12:29            274
# unkownhihi/deepfake                               DeepFake(150*150)                         763MB  2020-01-15 22:28:29            511
# dagnelies/deepfake-faces                          deepfake_faces                            433MB  2020-02-02 19:44:24           1048
# humananalog/deepfakes-inference-demo              Deepfakes Inference Demo                   81MB  2020-01-21 12:51:52           2035
# khoongweihao/deepfake-kernel-data                 Deepfake Kernel Data                       78MB  2020-02-28 13:47:55            112
# ...

# %%
# !kaggle competitions list -s deepfake
# Out:
# ...
# ref                           deadline             category      reward  teamCount  userHasEntered
# ----------------------------  -------------------  --------  ----------  ---------  --------------
# deepfake-detection-challenge  2020-04-23 22:17:00  Featured  $1,000,000       2265            True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Kaggle
# Out:
# /content/drive/MyDrive/Kaggle

# %%
#Download credit card fraud detection from Kaggle API
# !kaggle datasets download -d dagnelies/deepfake-faces
# Out:
# ...
#  99% 430M/433M [00:05<00:00, 112MB/s]
# 100% 433M/433M [00:05<00:00, 84.6MB/s]

# %%
# !unzip deepfake-faces.zip -d deepfakes
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: deepfakes/faces_224/yppwksjuui.jpg
#   inflating: deepfakes/faces_224/yppybofyww.jpg
#   inflating: deepfakes/faces_224/ypqjxdwawy.jpg
#   inflating: deepfakes/faces_224/ypqsxalhkw.jpg
#   inflating: deepfakes/faces_224/ypqxbbydxe.jpg
#   inflating: deepfakes/faces_224/ypqzrivawi.jpg
#   inflating: deepfakes/faces_224/yprdarrkit.jpg
#   inflating: deepfakes/faces_224/yprhthcacq.jpg
#   inflating: deepfakes/faces_224/yprmkhffdi.jpg
#   inflating: deepfakes/faces_224/yprnmqkhga.jpg
#   inflating: deepfakes/faces_224/yprqkgcoid.jpg
#   inflating: deepfakes/faces_224/yprsoygtjn.jpg
#   inflating: deepfakes/faces_224/yprxcbpmaj.jpg
#   inflating: deepfakes/faces_224/yprxtgidkk.jpg
#   inflating: deepfakes/faces_224/ypsbicsrsf.jpg
#   inflating: deepfakes/faces_224/ypsfvpanpn.jpg
#   inflating: deepfakes/faces_224/ypsgzbgbaz.jpg
#   inflating: deepfakes/faces_224/ypskfnxajx.jpg
# ...
